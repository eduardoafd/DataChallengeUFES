# %% [markdown]
# # Data Challenge

# %%
from glob import glob

# APIs algébricas, matemáticas e para tratamento e manipulação de dados
import numpy as np
import pandas as pd

# APIs para visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns

# Configuração das APIs de visualização
plt.rcParams.update({'figure.figsize': (13,13)})

# APIs para aprendizado de máquina
#import tensorflow as tf
# !pip install -U ppscore
import ppscore as pps
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Set de configurações de formatação

# %%
plt.style.use('default')

plt.rcParams.update({
    'font.size': 16,
    'axes.linewidth': 2,
    'axes.titlesize': 20,
    'axes.edgecolor': 'black',
    'axes.labelsize': 20,
    'axes.grid': True,
    'lines.linewidth': 1.5,
    'lines.markersize': 6,
    'figure.figsize': (15, 6),
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'Arial',
    'legend.fontsize': 13,
    'legend.framealpha': 1,
    'legend.edgecolor': 'black',
    'legend.shadow': False,
    'legend.frameon': True,
    })

# %% [markdown]
# # Trabalhando com o DataFrame

# %%
dataFiles = sorted(glob('Training/Small/Sample**.csv'))

# %%
dataFiles.extend(sorted(glob('Training/Large/Sample**.csv')))

# %%
#Criando dataFrames para cada arquivo
dataFrames = []

particleSizeData = pd.read_csv('Training/Training Operation Profiles of Samples.csv', ';')
for file in dataFiles:
    df = pd.read_csv(file)
    df["Pressure_Diferential(psi)"] = df["Upstream_Pressure(psi)"] - df["Downstream_Pressure(psi)"] #Calculo da perda de Carga
    df["sample"] = int(file[-6:-4])
    df.join(particleSizeData.set_index('sample'), on='sample')
    df['threshold'] = [0 if value < 20 else 1 for value in df['Pressure_Diferential(psi)']] #Definindo limiar de perda de carga
    dataFrames.append(df)

# %%
#Encontrando o primeiro valor com perda de carga maior que 20 psi
limits = []
for df in dataFrames:
    for value,time in zip(df['threshold'],df['Time(s)']):
        if (value == 1) :
            limits.append(time)
            break;

# %%
#Criando coluna de vida util remanscente
for df,limit in zip(dataFrames, limits):
    df['Remaining Lifespan(s)'] = [(limit - instant) if (instant < limit) else 0 for instant in df['Time(s)']];

# %%
#Unindo dataframes em um único
dataFrame = pd.concat(dataFrames).reset_index();

# %% [markdown]
# # Análise Exploratória dos Dados

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62824 entries, 0 to 62823
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      62824 non-null  int64
#  1   Time(s)                    62824 non-null  float64
#  2   Flow_Rate(ml/m)            62824 non-null  float64
#  3   Upstream_Pressure(psi)     62824 non-null  float64
#  4   Downstream_Pressure(psi)   62824 non-null  float64
#  5   Pressure_Diferential(psi)  62824 non-null  float64
#  6   sample                     62824 non-null  int64
#  7   threshold                  62824 non-null  int64
#  8   Remaining Lifespan(s)      62824 non-null  float64
# dtypes: float64(6), int64(3)
# memory usage: 4.3 MB

# %%
pressoes = dataFrame.columns.values.tolist()
pressoes.remove('index')
pressoes.remove('sample')
pressoes.remove('threshold')
pressoes.remove('Time(s)')

# %%
len(pressoes)
# Out:
# 5

# %%
Df = dataFrame.assign(Particles=1)
Df.loc[((Df['sample']>=1) & (Df['sample']<=12)),'Particles'] = 0

# %%
#len(Df.loc[((Df['sample']>=1) & (Df['sample']<=12))])
Df.groupby('Particles')

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.countplot(data=Df, x='Particles', ax=ax)
# Out:
# <AxesSubplot:xlabel='Particles', ylabel='count'>

# %%
data_description=Df.describe()
data_description
# Out:
#               index       Time(s)  Flow_Rate(ml/m)  Upstream_Pressure(psi)  \
# count  62824.000000  62824.000000     62824.000000            62824.000000
# mean    1342.340443    134.234044       523.405825                5.683977
# std      814.700696     81.470070       101.318216                8.280750
# min        0.000000      0.000000        -3.687368               -3.900000
# 25%      654.000000     65.400000       535.583386                0.975000
# 50%     1308.000000    130.800000       557.300312                1.987500
# 75%     1963.000000    196.300000       563.223110                4.793750
# max     3539.000000    353.900000       931.325003               35.306250
#
#        Downstream_Pressure(psi)  Pressure_Diferential(psi)        sample  \
# count              62824.000000               62824.000000  62824.000000
# mean                   0.010881                   5.673095     20.116325
# ...

# %%
Df_col = ['index',	'Time(s)',	'Flow_Rate(ml/m)',	'Upstream_Pressure(psi)',	'Downstream_Pressure(psi)',	'Pressure_Diferential(psi)',	'sample',	'threshold',	'Remaining Lifespan(s)'	,'Particles']
Df_col
# Out:
# ['index',
#  'Time(s)',
#  'Flow_Rate(ml/m)',
#  'Upstream_Pressure(psi)',
#  'Downstream_Pressure(psi)',
#  'Pressure_Diferential(psi)',
#  'sample',
#  'threshold',
#  'Remaining Lifespan(s)',
#  'Particles']

# %%
#axes = data_description.T.plot.bar(subplots=True, figsize=(15,10))
Df
# Out:
#        index  Time(s)  Flow_Rate(ml/m)  Upstream_Pressure(psi)  \
# 0          0      0.0         9.935067                -0.30000
# 1          1      0.1         4.110983                 0.61250
# 2          2      0.2         5.098116                 1.05625
# 3          3      0.3        10.231207                 1.20000
# 4          4      0.4         8.355655                 0.93125
# ...      ...      ...              ...                     ...
# 62819   2185    218.5       208.447512                16.95000
# 62820   2186    218.6       210.717918                17.22500
# 62821   2187    218.7       208.546225                17.39375
# 62822   2188    218.8       204.795120                17.17500
# 62823   2189    218.9       199.662029                16.91875
#
#        Downstream_Pressure(psi)  Pressure_Diferential(psi)  sample  threshold  \
# 0                      -1.10625                    0.80625       1          0
# ...

# %%
Df_plot = Df.copy()[Df_col]
df_corr = Df_plot.corr(method='pearson')
fig, ax = plt.subplots(figsize=(15,15))
axes = sns.heatmap(df_corr, linewidths=.2, )

# %%
Df=Df.assign(Lifespan=0)
Df

# %%
# Df["Remaining Lifespan(s)"].loc[((Df['sample']>=1) & (Df['sample']<=12))].loc[(Df["Remaining Lifespan(s)"]>0)]
# Df["Remaining Lifespan(s)"].loc[((Df['sample']>=1) & (Df['sample']<=12))]

# Df["Remaining Lifespan(s)"].loc[((Df['sample']>=33) & (Df['sample']<=44))].loc[(Df["Remaining Lifespan(s)"]>0)]
# Df["Remaining Lifespan(s)"].loc[((Df['sample']>=33) & (Df['sample']<=44))]

# Df.loc[(Df["index"]==1000)]
VidaReversa=Df["Remaining Lifespan(s)"]
VidaReversa = VidaReversa**-1
VidaReversa
# Df["Lifespan"] = VidaReversa
# Df.iloc[20]
# len(VidaReversa)
for i in range(len(Df)):
    Df["Lifespan"].iloc[i] = Df["Remaining Lifespan(s)"].max() - Df["Remaining Lifespan(s)"].iloc[i]
   
Df["Lifespan"]
# Out:
# 0          4.1
# 1          4.2
# 2          4.3
# 3          4.4
# 4          4.5
#          ...
# 62819    277.5
# 62820    277.5
# 62821    277.5
# 62822    277.5
# 62823    277.5
# Name: Lifespan, Length: 62824, dtype: float64

# %%
# ax= sns.boxplot(x="Remaining Lifespan(s)", y="Particles",data=Df)

# %%
Df.iloc[62822]
# Out:
# index                        2188.00000
# Time(s)                       218.80000
# Flow_Rate(ml/m)               204.79512
# Upstream_Pressure(psi)         17.17500
# Downstream_Pressure(psi)        0.31875
# Pressure_Diferential(psi)      16.85625
# sample                         44.00000
# threshold                       0.00000
# Remaining Lifespan(s)           0.00000
# Particles                       1.00000
# Lifespan                            inf
# Name: 62822, dtype: float64

# %%
n_cols = 3
n_rows = 4//3 + 1

fig, ax = plt.subplots(ncols = n_cols, nrows = n_rows, figsize = (13*n_cols, 13*n_rows))
ax = ax.reshape((n_cols*n_rows,))
aux_df1 = Df.groupby('Particles')
tam=len(pressoes)

for pressao in range(len(pressoes)):  
    ax[pressao].set_title(f'{pressoes[pressao]}', size = 20)
    sns.kdeplot(data = aux_df1.get_group(0)[pressoes[pressao]], ax = ax[pressao], label = 'Partículas pequenas')
    sns.kdeplot(data = aux_df1.get_group(1)[pressoes[pressao]], ax = ax[pressao], label = 'Partículas grandes')
    
    ax[pressao].legend()
    ax[pressao].grid()

# %%
sns.relplot(y="Pressure_Diferential(psi)", x="Flow_Rate(ml/m)",hue="Particles", 
            col="Particles", data=Df);

#(Df.loc[((Df['sample']>=1) & (Df['sample']<=12))])
#sns.relplot(x=Df["Particles"],y=Df["Pressure_Diferential(psi)"],kind="line", data=Df)

# %%
sns.relplot(x=Df["Particles"],y=Df["Flow_Rate(ml/m)"],kind="line", data=Df)

# %%
g=sns.relplot(x="Remaining Lifespan(s)", y="Flow_Rate(ml/m)",hue="Particles", 
            col="Particles", data=Df);
g.set(ylim=(200, 700))

# %%
h=sns.relplot(x="Remaining Lifespan(s)", y="Pressure_Diferential(psi)",hue="Particles", 
            col="Particles", data=Df);
h.set(ylim=(None,25))

# %%
sns.relplot(x="Remaining Lifespan(s)", y="Pressure_Diferential(psi)",hue="Particles", 
            col="Particles", data=Df);

# %%
fig, ax = plt.subplots(ncols = 1, nrows = len(pressoes), figsize = (10, 5*len(pressoes)))
ax = ax.reshape((len(pressoes),))
aux_df = Df.groupby('Particles')

for pressao in range(len(pressoes)):  
    ax[pressao].set_title(f'{pressoes[pressao]}', size = 20)
    
    #sns.scatterplot(data = aux_df, x = 'Remaining Lifespan(s)', y= 'Flow_rate(ml/m)', label = 'Partículas pequenas', hue = 'sample')

    sns.scatterplot(data = aux_df.get_group(0)[pressoes[pressao]], ax = ax[pressao], label = 'Partículas pequenas')
    sns.scatterplot(data = aux_df.get_group(1)[pressoes[pressao]], ax = ax[pressao], label = 'Partículas grandes')
    
    ax[pressao].legend()
    ax[pressao].grid()

    
# seaborn
# hue

# %%
sns.scatterplot(data = Df, x = 'Remaining Lifespan(s)', y= 'Flow_Rate(ml/m)', hue = 'sample', style= 'Particles', palette= 'Set1')
# Out:
# <AxesSubplot:xlabel='Remaining Lifespan(s)', ylabel='Flow_Rate(ml/m)'>

# %%
sns.scatterplot(data = Df, x = 'Remaining Lifespan(s)', y= 'Pressure_Diferential(psi)', hue = 'sample', style= 'Particles', palette= 'Set1')
# Out:
# <AxesSubplot:xlabel='Remaining Lifespan(s)', ylabel='Pressure_Diferential(psi)'>

# %%
sns.scatterplot(data = Df.loc[(Df['Particles'])==0], x = 'Remaining Lifespan(s)', y= 'Flow_Rate(ml/m)', hue = 'sample', style= 'Particles', palette= 'Set1')
# Out:
# <AxesSubplot:xlabel='Remaining Lifespan(s)', ylabel='Flow_Rate(ml/m)'>

# %%
sns.scatterplot(data = Df.loc[(Df['Particles'])==1], x = 'Remaining Lifespan(s)', y= 'Flow_Rate(ml/m)', hue = 'sample', style= 'Particles', palette= 'Set1')
# Out:
# <AxesSubplot:xlabel='Remaining Lifespan(s)', ylabel='Flow_Rate(ml/m)'>

# %%
sns.boxplot(x=Df['Particles'],y=[Df['Pressure_Diferential(psi)'], Df['Flow_Rate(ml/m)'], Df['Remaining Lifespan(s)']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1471             try:
# -> 1472                 order = vector.cat.categories
#    1473             except (TypeError, AttributeError):
#
# AttributeError: 'list' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1475                 try:
# -> 1476                     order = vector.unique()
#    1477                 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'unique'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# A partir daqui vem o proposto pelo Pires

data = pd.concat((pd.read_csv(file).assign(sample = int(file[-6:-4]) for file in dataFiles), ignore_index = True)
# Out:
#   File "<ipython-input-23-6627949b3720>", line 3
#     data = pd.concat((pd.read_csv(file).assign(sample = int(file[-6:-4]) for file in dataFiles), ignore_index = True)
#                                                                          ^
# SyntaxError: invalid syntax

# %%
particleSizeData = pd.read_csv('Training/Training Operation Profiles of Samples.csv', ';')

# %%
data.join(particleSizeData.set_index('sample'), on='sample')

# %%
data["Pressure_Diferential(psi)"] = data["Upstream_Pressure(psi)"] - data["Downstream_Pressure(psi)"]
