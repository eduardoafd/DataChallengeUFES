# %% [markdown]
# # Data Challenge

# %%
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt

# %%
dataFiles = sorted(glob('Training/Small/Sample**.csv'))

# %%
dataFrames = []
plt.figure(figsize=(8, 6), dpi=100)
for file in dataFiles:
    df = pd.read_csv(file)
    df["Pressure_Diferential(psi)"] = df["Upstream_Pressure(psi)"] - df["Downstream_Pressure(psi)"]
    dataFrames.append(df)
    plt.plot(df['Time(s)'], df['Pressure_Diferential(psi)'])
    plt.xlabel('Tempo (s)')
    plt.ylabel('Perda de Carga (psi)')
    
plt.plot([0, 350], [20, 20], 'black')

#Colocar legendas

# %%
data = pd.concat((pd.read_csv(file).assign(filename = file) for file in dataFiles), ignore_index = True)

# %%
data
# Out:
#        Time(s)  Flow_Rate(ml/m)  Upstream_Pressure(psi)  \
# 0          0.0         9.935067                -0.30000
# 1          0.1         4.110983                 0.61250
# 2          0.2         5.098116                 1.05625
# 3          0.3        10.231207                 1.20000
# 4          0.4         8.355655                 0.93125
# ...        ...              ...                     ...
# 35639    254.5       284.061899                10.38750
# 35640    254.6       278.830095                10.68750
# 35641    254.7       270.735604                 9.50000
# 35642    254.8       189.000992                 8.36250
# 35643    254.9       265.701226                 9.40000
#
#        Downstream_Pressure(psi)                     filename
# 0                      -1.10625  Training/Small/Sample01.csv
# 1                      -0.34375  Training/Small/Sample01.csv
# 2                      -0.08125  Training/Small/Sample01.csv
# 3                       0.84375  Training/Small/Sample01.csv
# 4                       0.79375  Training/Small/Sample01.csv
# ...                         ...                          ...
# 35639                   0.45000  Training/Small/Sample12.csv
# 35640                   0.40000  Training/Small/Sample12.csv
# 35641                  -0.93125  Training/Small/Sample12.csv
# 35642                  -0.85000  Training/Small/Sample12.csv
# 35643                   0.36250  Training/Small/Sample12.csv
#
# [35644 rows x 5 columns]

# %%
data
# Out:
#        Time(s)  Flow_Rate(ml/m)  Upstream_Pressure(psi)  \
# 0          0.0         9.935067                -0.30000
# 1          0.1         4.110983                 0.61250
# 2          0.2         5.098116                 1.05625
# 3          0.3        10.231207                 1.20000
# 4          0.4         8.355655                 0.93125
# ...        ...              ...                     ...
# 35639    254.5       284.061899                10.38750
# 35640    254.6       278.830095                10.68750
# 35641    254.7       270.735604                 9.50000
# 35642    254.8       189.000992                 8.36250
# 35643    254.9       265.701226                 9.40000
#
#        Downstream_Pressure(psi)                     filename
# 0                      -1.10625  Training/Small/Sample01.csv
# 1                      -0.34375  Training/Small/Sample01.csv
# 2                      -0.08125  Training/Small/Sample01.csv
# 3                       0.84375  Training/Small/Sample01.csv
# 4                       0.79375  Training/Small/Sample01.csv
# ...                         ...                          ...
# 35639                   0.45000  Training/Small/Sample12.csv
# 35640                   0.40000  Training/Small/Sample12.csv
# 35641                  -0.93125  Training/Small/Sample12.csv
# 35642                  -0.85000  Training/Small/Sample12.csv
# 35643                   0.36250  Training/Small/Sample12.csv
#
# [35644 rows x 5 columns]
